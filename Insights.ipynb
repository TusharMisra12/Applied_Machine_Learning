# %%
#20BHI10028 - TUSHAR MISRA
from sklearn import tree
from pandas import read_csv
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df=read_csv("data.csv")

# %%
df
# Out:
#                      date         price  bedrooms  bathrooms  sqft_living  \
# 0     2014-05-02 00:00:00  3.130000e+05       3.0       1.50         1340
# 1     2014-05-02 00:00:00  2.384000e+06       5.0       2.50         3650
# 2     2014-05-02 00:00:00  3.420000e+05       3.0       2.00         1930
# 3     2014-05-02 00:00:00  4.200000e+05       3.0       2.25         2000
# 4     2014-05-02 00:00:00  5.500000e+05       4.0       2.50         1940
# ...                   ...           ...       ...        ...          ...
# 4595  2014-07-09 00:00:00  3.081667e+05       3.0       1.75         1510
# 4596  2014-07-09 00:00:00  5.343333e+05       3.0       2.50         1460
# 4597  2014-07-09 00:00:00  4.169042e+05       3.0       2.50         3010
# 4598  2014-07-10 00:00:00  2.034000e+05       4.0       2.00         2090
# 4599  2014-07-10 00:00:00  2.206000e+05       3.0       2.50         1490
#
#       sqft_lot  floors  waterfront  view  condition  sqft_above  \
# ...

# %%
df.hist()
plt.show()

# %%
df.plot.bar()
plt.show()

# %%
df1=read_csv("data1.csv")

# %%
df1
# Out:
#                   date         price  bedrooms  bathrooms  sqft_living  \
# 0     02-05-2014 00:00  3.130000e+05         3       1.50         1340
# 1     02-05-2014 00:00  2.384000e+06         5       2.50         3650
# 2     02-05-2014 00:00  3.420000e+05         3       2.00         1930
# 3     02-05-2014 00:00  4.200000e+05         3       2.25         2000
# 4     02-05-2014 00:00  5.500000e+05         4       2.50         1940
# ...                ...           ...       ...        ...          ...
# 4595  09-07-2014 00:00  3.081667e+05         3       1.75         1510
# 4596  09-07-2014 00:00  5.343333e+05         3       2.50         1460
# 4597  09-07-2014 00:00  4.169042e+05         3       2.50         3010
# 4598  10-07-2014 00:00  2.034000e+05         4       2.00         2090
# 4599  10-07-2014 00:00  2.206000e+05         3       2.50         1490
#
#       floors  condition       city  statezip country
# 0        1.5          3  Shoreline  WA 98133     USA
# ...

# %%
df1.hist()
plt.show()

# %%
df1.plot.bar()
plt.show()

# %%
plt.scatter(df1['price'],df1['bedrooms'])
plt.xlabel('price')
plt.ylabel('bedrooms')
plt.title('Scatter Plot on House Price Dataset')
# Out:
# Text(0.5, 1.0, 'Scatter Plot on House Price Dataset')

# %%
plt.pie(df1['bedrooms'])
plt.show()

# %%
labels=['0-50','51-100','101-150','151-200','201-250','251-300']
colors=['red','blue','green','orange','yellow','black']
sizes=[50,100,150,200,250,300]
plt.pie(sizes,labels=labels, colors=colors, startangle=90, autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
# Using forward fill
df=df.fillna(method='ffill')
df1.head(10)
# Out:
#                date      price  bedrooms  bathrooms  sqft_living  floors  \
# 0  02-05-2014 00:00   313000.0         3       1.50         1340     1.5
# 1  02-05-2014 00:00  2384000.0         5       2.50         3650     2.0
# 2  02-05-2014 00:00   342000.0         3       2.00         1930     1.0
# 3  02-05-2014 00:00   420000.0         3       2.25         2000     1.0
# 4  02-05-2014 00:00   550000.0         4       2.50         1940     1.0
# 5  02-05-2014 00:00   490000.0         2       1.00          880     1.0
# 6  02-05-2014 00:00   335000.0         2       2.00         1350     1.0
# 7  02-05-2014 00:00   482000.0         4       2.50         2710     2.0
# 8  02-05-2014 00:00   452500.0         3       2.50         2430     1.0
# 9  02-05-2014 00:00   640000.0         4       2.00         1520     1.5
#
#    condition          city  statezip country
# 0          3     Shoreline  WA 98133     USA
# 1          5       Seattle  WA 98119     USA
# ...

# %%
# but we do not want this fillna operation to execute on some columns
df['price'].fillna(method='bfill')
df.head(10)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
#Replace Using Mean, Median, or Mode
median=df['price'].median()
df['price'].fillna(median,inplace=True)
df.head(10)
# Out:
#                   date      price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0  2014-05-02 00:00:00   313000.0       3.0       1.50         1340      7912
# 1  2014-05-02 00:00:00  2384000.0       5.0       2.50         3650      9050
# 2  2014-05-02 00:00:00   342000.0       3.0       2.00         1930     11947
# 3  2014-05-02 00:00:00   420000.0       3.0       2.25         2000      8030
# 4  2014-05-02 00:00:00   550000.0       4.0       2.50         1940     10500
# 5  2014-05-02 00:00:00   490000.0       2.0       1.00          880      6380
# 6  2014-05-02 00:00:00   335000.0       2.0       2.00         1350      2560
# 7  2014-05-02 00:00:00   482000.0       4.0       2.50         2710     35868
# 8  2014-05-02 00:00:00   452500.0       3.0       2.50         2430     88426
# 9  2014-05-02 00:00:00   640000.0       4.0       2.00         1520      6200
#
#    floors  waterfront  view  condition  sqft_above  sqft_basement  yr_built  \
# ...

# %%
df=df[0:50]
df.plot(kind = 'scatter', x = 'condition', y = 'price')
plt.show()

# %%
df.plot(kind = 'bar', x = 'sqft_living', y = 'price')
plt.show()

# %%
x=df[['bathrooms','bedrooms','price']]
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler(feature_range=(0,1))
rescaledx=scaler.fit_transform(x)
rescaledx
# Out:
# array([[0.25      , 0.33333333, 0.03629595],
#        [0.75      , 1.        , 1.        ],
#        [0.5       , 0.33333333, 0.0497906 ],
#        [0.625     , 0.33333333, 0.08608655],
#        [0.75      , 0.66666667, 0.1465798 ],
#        [0.        , 0.        , 0.11865984],
#        [0.5       , 0.        , 0.04653327],
#        [0.75      , 0.66666667, 0.11493718],
#        [0.75      , 0.33333333, 0.10120987],
#        [0.5       , 0.66666667, 0.18845975],
#        [0.375     , 0.33333333, 0.10609586],
#        [0.75      , 0.66666667, 0.54211261],
#        [0.375     , 0.33333333, 0.16449511],
#        [0.        , 0.33333333, 0.06049325],
#        [0.875     , 1.        , 0.44904607],
#        [0.25      , 0.33333333, 0.00349   ],
#        [0.25      , 0.33333333, 0.08562122],
#        [1.        , 0.66666667, 0.06165658],
#        [0.375     , 0.33333333, 0.01067939],
#        [0.25      , 0.33333333, 0.01861331],
#        [0.375     , 0.33333333, 0.23964635],
# ...

# %%
x=df[['bathrooms','bedrooms','price']]
from sklearn.preprocessing import StandardScaler 
scaler=StandardScaler().fit(x)
rescaledx
# Out:
# array([[0.25      , 0.33333333, 0.03629595],
#        [0.75      , 1.        , 1.        ],
#        [0.5       , 0.33333333, 0.0497906 ],
#        [0.625     , 0.33333333, 0.08608655],
#        [0.75      , 0.66666667, 0.1465798 ],
#        [0.        , 0.        , 0.11865984],
#        [0.5       , 0.        , 0.04653327],
#        [0.75      , 0.66666667, 0.11493718],
#        [0.75      , 0.33333333, 0.10120987],
#        [0.5       , 0.66666667, 0.18845975],
#        [0.375     , 0.33333333, 0.10609586],
#        [0.75      , 0.66666667, 0.54211261],
#        [0.375     , 0.33333333, 0.16449511],
#        [0.        , 0.33333333, 0.06049325],
#        [0.875     , 1.        , 0.44904607],
#        [0.25      , 0.33333333, 0.00349   ],
#        [0.25      , 0.33333333, 0.08562122],
#        [1.        , 0.66666667, 0.06165658],
#        [0.375     , 0.33333333, 0.01067939],
#        [0.25      , 0.33333333, 0.01861331],
#        [0.375     , 0.33333333, 0.23964635],
# ...

# %%
x=df[['bathrooms','bedrooms','price']][0:20]
x.dropna(inplace=True)
from sklearn.decomposition import PCA
pca=PCA(n_components=3)
fit=pca.fit(x)
features=fit.transform(x)
features
# Out:
# array([[-2.86347500e+05,  2.47443646e-01, -2.53351368e-01],
#        [ 1.78465250e+06,  4.74059485e-01, -3.24913440e-02],
#        [-2.57347500e+05, -3.68090857e-02,  1.42632897e-01],
#        [-1.79347500e+05, -1.05161829e-01,  3.62727634e-01],
#        [-4.93475000e+04, -8.84881848e-01, -3.49671035e-02],
#        [-1.09347500e+05,  1.54280531e+00,  5.82565538e-02],
#        [-2.64347500e+05,  7.26838712e-01,  7.76085635e-01],
#        [-1.17347500e+05, -9.63883523e-01, -5.86360351e-02],
#        [-1.46847500e+05, -2.26375986e-01,  5.66985072e-01],
#        [ 4.06525000e+04, -4.62376184e-01, -3.89530738e-01],
#        [-1.36347500e+05,  2.62739736e-01, -8.19540865e-03],
#        [ 8.00652500e+05,  1.02639094e-01,  2.60894540e-01],
#        [-1.08475000e+04,  4.08544299e-01,  3.54876929e-02],
#        [-2.34347500e+05,  6.25801315e-01, -6.21141758e-01],
#        [ 6.00652500e+05, -1.06047141e+00, -2.51664130e-01],
#        [-3.56847500e+05,  1.65537498e-01, -2.77890480e-01],
# ...
